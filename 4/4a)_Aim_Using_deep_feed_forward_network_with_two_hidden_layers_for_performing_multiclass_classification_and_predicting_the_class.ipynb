# %%
from keras.models import Sequential
from keras.layers import Dense
from sklearn.datasets import make_blobs
from sklearn.preprocessing import MinMaxScaler
X,Y=make_blobs(n_samples=100,centers=2,n_features=2,random_state=1)
scalar=MinMaxScaler()
scalar.fit(X)
X=scalar.transform(X)
model=Sequential()
model.add(Dense(4,input_dim=2,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam')
model.fit(X,Y,epochs=50)
Xnew,Yreal=make_blobs(n_samples=3,centers=2,n_features=2,random_state=1)
Xnew=scalar.transform(Xnew)
#Ynew=model.predict_classes(Xnew)

Ynew = (model.predict(Xnew) > 0.5).astype("int32")

for i in range(len(Xnew)):
  print("X=%s,Predicted=%s,Desired=%s"%(Xnew[i],Ynew[i],Yreal[i]))
# Out:
# Epoch 1/50
# 4/4 [==============================] - 1s 4ms/step - loss: 0.5959
# Epoch 2/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5934
# Epoch 3/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5910
# Epoch 4/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5883
# Epoch 5/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5856
# Epoch 6/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5828
# Epoch 7/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5800
# Epoch 8/50
# 4/4 [==============================] - 0s 6ms/step - loss: 0.5772
# Epoch 9/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5743
# Epoch 10/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5713
# Epoch 11/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5680
# Epoch 12/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5646
# Epoch 13/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5611
# Epoch 14/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5575
# Epoch 15/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5538
# Epoch 16/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5502
# Epoch 17/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5465
# Epoch 18/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5428
# Epoch 19/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5393
# Epoch 20/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5360
# Epoch 21/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5327
# Epoch 22/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5295
# Epoch 23/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5264
# Epoch 24/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5232
# Epoch 25/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5202
# Epoch 26/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5169
# Epoch 27/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5135
# Epoch 28/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5099
# Epoch 29/50
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5064
# Epoch 30/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5029
# Epoch 31/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4995
# Epoch 32/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4962
# Epoch 33/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4927
# Epoch 34/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4892
# Epoch 35/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4858
# Epoch 36/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4825
# Epoch 37/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4791
# Epoch 38/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4757
# Epoch 39/50
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4723
# Epoch 40/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4689
# Epoch 41/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4656
# Epoch 42/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4622
# Epoch 43/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4589
# Epoch 44/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4556
# Epoch 45/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4523
# Epoch 46/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4491
# Epoch 47/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4458
# Epoch 48/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4427
# Epoch 49/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4395
# Epoch 50/50
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4364
# 1/1 [==============================] - 0s 85ms/step
# X=[0.89337759 0.65864154],Predicted=[0],Desired=0
# X=[0.29097707 0.12978982],Predicted=[1],Desired=1
# X=[0.78082614 0.75391697],Predicted=[0],Desired=0
