# %%
import keras
from keras import layers
from keras.datasets import mnist
import numpy as np
encoding_dim=32
#this is our input image
input_img=keras.Input(shape=(784,))
#"encoded" is the encoded representation of the input
encoded=layers.Dense(encoding_dim, activation='relu')(input_img)
#"decoded" is the lossy reconstruction of the input
decoded=layers.Dense(784, activation='sigmoid')(encoded)
#creating autoencoder model
autoencoder=keras.Model(input_img,decoded)
#create the encoder model
encoder=keras.Model(input_img,encoded)
encoded_input=keras.Input(shape=(encoding_dim,))
#Retrive the last layer of the autoencoder model
decoder_layer=autoencoder.layers[-1]
#create the decoder model
decoder=keras.Model(encoded_input,decoder_layer(encoded_input))
autoencoder.compile(optimizer='adam',loss='binary_crossentropy')
#scale and make train and test dataset
(X_train,_),(X_test,_)=mnist.load_data()
X_train=X_train.astype('float32')/255.
X_test=X_test.astype('float32')/255.
X_train=X_train.reshape((len(X_train),np.prod(X_train.shape[1:])))
X_test=X_test.reshape((len(X_test),np.prod(X_test.shape[1:])))
print(X_train.shape)
print(X_test.shape)
#train autoencoder with training dataset
autoencoder.fit(X_train,X_train,
 epochs=50,
 batch_size=256,
 shuffle=True,
 validation_data=(X_test,X_test))
encoded_imgs=encoder.predict(X_test)
decoded_imgs=decoder.predict(encoded_imgs)
import matplotlib.pyplot as plt
n = 10 # How many digits we will display
plt.figure(figsize=(40, 4))
for i in range(10):
 # display original
 ax = plt.subplot(3, 20, i + 1)
 plt.imshow(X_test[i].reshape(28, 28))
 plt.gray()
 ax.get_xaxis().set_visible(False)
 ax.get_yaxis().set_visible(False)
 # display encoded image
 ax = plt.subplot(3, 20, i + 1 + 20)
 plt.imshow(encoded_imgs[i].reshape(8,4))
 plt.gray()
 ax.get_xaxis().set_visible(False)
 ax.get_yaxis().set_visible(False)
 # display reconstruction
 ax = plt.subplot(3, 20, 2*20 +i+ 1)
 plt.imshow(decoded_imgs[i].reshape(28, 28))
 plt.gray()
 ax.get_xaxis().set_visible(False)
 ax.get_yaxis().set_visible(False)
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# (60000, 784)
# (10000, 784)
# Epoch 1/50
# 235/235 [==============================] - 6s 22ms/step - loss: 0.2795 - val_loss: 0.1927
# Epoch 2/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.1730 - val_loss: 0.1557
# Epoch 3/50
# 235/235 [==============================] - 6s 25ms/step - loss: 0.1462 - val_loss: 0.1344
# Epoch 4/50
# 235/235 [==============================] - 5s 20ms/step - loss: 0.1289 - val_loss: 0.1215
# Epoch 5/50
# 235/235 [==============================] - 5s 23ms/step - loss: 0.1184 - val_loss: 0.1127
# Epoch 6/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.1111 - val_loss: 0.1069
# Epoch 7/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1060 - val_loss: 0.1027
# Epoch 8/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1025 - val_loss: 0.0997
# Epoch 9/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.1000 - val_loss: 0.0977
# Epoch 10/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0984 - val_loss: 0.0965
# Epoch 11/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0973 - val_loss: 0.0956
# Epoch 12/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0966 - val_loss: 0.0949
# Epoch 13/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0961 - val_loss: 0.0946
# Epoch 14/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0958 - val_loss: 0.0943
# Epoch 15/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0956 - val_loss: 0.0941
# Epoch 16/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0954 - val_loss: 0.0940
# Epoch 17/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0953 - val_loss: 0.0938
# Epoch 18/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0951 - val_loss: 0.0938
# Epoch 19/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0950 - val_loss: 0.0938
# Epoch 20/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0949 - val_loss: 0.0936
# Epoch 21/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0949 - val_loss: 0.0936
# Epoch 22/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0948 - val_loss: 0.0935
# Epoch 23/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0947 - val_loss: 0.0934
# Epoch 24/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0947 - val_loss: 0.0934
# Epoch 25/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0946 - val_loss: 0.0933
# Epoch 26/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0946 - val_loss: 0.0933
# Epoch 27/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0946 - val_loss: 0.0933
# Epoch 28/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0945 - val_loss: 0.0932
# Epoch 29/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0945 - val_loss: 0.0932
# Epoch 30/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0944 - val_loss: 0.0932
# Epoch 31/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0944 - val_loss: 0.0931
# Epoch 32/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0944 - val_loss: 0.0931
# Epoch 33/50
# 235/235 [==============================] - 4s 15ms/step - loss: 0.0943 - val_loss: 0.0931
# Epoch 34/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0943 - val_loss: 0.0931
# Epoch 35/50
# 235/235 [==============================] - 2s 11ms/step - loss: 0.0943 - val_loss: 0.0930
# Epoch 36/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0942 - val_loss: 0.0929
# Epoch 37/50
# 235/235 [==============================] - 3s 12ms/step - loss: 0.0942 - val_loss: 0.0932
# Epoch 38/50
# 235/235 [==============================] - 3s 15ms/step - loss: 0.0942 - val_loss: 0.0929
# Epoch 39/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0942 - val_loss: 0.0929
# Epoch 40/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0941 - val_loss: 0.0930
# Epoch 41/50
# 235/235 [==============================] - 2s 10ms/step - loss: 0.0941 - val_loss: 0.0929
# Epoch 42/50
# 235/235 [==============================] - 3s 13ms/step - loss: 0.0941 - val_loss: 0.0929
# Epoch 43/50
# 235/235 [==============================] - 4s 18ms/step - loss: 0.0941 - val_loss: 0.0929
# Epoch 44/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0941 - val_loss: 0.0929
# Epoch 45/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0940 - val_loss: 0.0928
# Epoch 46/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0940 - val_loss: 0.0929
# Epoch 47/50
# 235/235 [==============================] - 3s 14ms/step - loss: 0.0940 - val_loss: 0.0928
# Epoch 48/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0940 - val_loss: 0.0928
# Epoch 49/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0940 - val_loss: 0.0928
# Epoch 50/50
# 235/235 [==============================] - 3s 11ms/step - loss: 0.0940 - val_loss: 0.0928
# 313/313 [==============================] - 0s 1ms/step
# 313/313 [==============================] - 0s 1ms/step
